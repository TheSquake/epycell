# %% [markdown]
# # hxbook
#
# A terminal notebook with **inline figures** and a *live editor* in each cell.
#
# ## Features
# - Rendered **markdown** (this cell)
# - `inline code` and fenced blocks
# - Lists, headings, emphasis, blockquotes
#
# > Press `i` to edit the raw markdown, then save & quit to see it re-render.
#
# ### Code sample
# ```python
# import numpy as np
# print(np.pi)
# ```

# %%
import numpy as np
import matplotlib.pyplot as plt
print('loaded from sample.ipynb')

# %%
t = np.linspace(0, 4*np.pi, 400)
plt.figure()
plt.plot(t, np.sin(t) * np.exp(-t/8))
plt.title('damped sine — from file')
print('figure renders inline below')
